# %%
# !pip install pandas nltk gensim
# Out:
# Requirement already satisfied: pandas in .\venv1\Lib\site-packages (3.0.0)
# Requirement already satisfied: nltk in .\venv1\Lib\site-packages (3.9.2)
# Requirement already satisfied: gensim in .\venv1\Lib\site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.26.0 in .\venv1\Lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\venv1\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\venv1\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: click in .\venv1\Lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in .\venv1\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in .\venv1\Lib\site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: tqdm in .\venv1\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: scipy>=1.7.0 in .\venv1\Lib\site-packages (from gensim) (1.17.0)
# Requirement already satisfied: smart_open>=1.8.1 in .\venv1\Lib\site-packages (from gensim) (7.5.0)
# Requirement already satisfied: six>=1.5 in .\venv1\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: wrapt in .\venv1\Lib\site-packages (from smart_open>=1.8.1->gensim) (2.1.1)
# Requirement already satisfied: colorama in .\venv1\Lib\site-packages (from click->nltk) (0.4.6)

# %%
import pandas as pd
import re
import nltk

from nltk.stem import WordNetLemmatizer
from gensim.utils import simple_preprocess
from gensim.models import Word2Vec

# Download required NLTK data
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
messages = pd.read_csv(
    'spam_and_ham_classification.csv',
    encoding='latin-1'
)

messages.head()
# Out:
#   label                                               text
# 0   ham  into the kingdom of god and those that are ent...
# 1  spam  there was flow at hpl meter 1505 on april firs...
# 2   ham  take a look at this one campaign for bvyhprice...
# 3  spam  somu wrote actually thats what i was looking f...
# 4  spam  fathi boudra wrote i fixed the issue in the sv...

# %%
lemmatizer = WordNetLemmatizer()

corpus = []

for text in messages['text']:
    text = re.sub('[^a-zA-Z]', ' ', str(text))
    text = text.lower().split()
    text = [lemmatizer.lemmatize(word) for word in text]
    corpus.append(' '.join(text))

corpus[:5]
# Out:
# ['into the kingdom of god and those that are entering in he lord pardon escapenumber u in this thing we pray thee have u excused escapenumbernot therefore o escapenumber believer to look into the grave for to you it the holy ghost and escapenumber therefore being a holy habitation unto forth the word of truth and escapenumber soberness escapenumber but in all probability hath made them mad escapenumber and though escapenumber blessed be god all do that of jesus christ they see the necessity of escapenumber closing with a more than almost christian but is heaven so small a escapenumber trifle in men s esteem a not to be total renovation of the whole man escapenumber by the righteousness of complete though we be delivered from the power escapenumber we are not candle of the lord shine out and your redeemer lift up the escapenumber inward holiness a indeed sometimes they do though in a worm destroy escapenumber them yet even in their flesh shall they see a mind to see jesus but escapenumber then they cannot come to him jeannine walsh',
#  'there wa flow at hpl meter on april first that didn t have a deal ticket out there but now there is a deal ticket out there to cover it please link it or whatever you have to do to make it work thanks lee',
#  'take a look at this one campaign for bvyhprice escapenumber escapenumber escapenumber day target price escapenumber escapenumbermarket hellish this sym is gaining momentum see the news theescapenumber call your broker',
#  'somu wrote actually thats what i wa looking for l o r so if the user entered string is to be matched for lpt then i ll use l p t and to match npr i use n p r somu you need to tell u exactly what match you want otherwise we can t tell you whether something will work or not are you simply checking whether the input string contains all of the match character i would forget about sorting the input string and do it a in the program below but please explain what the problem is instead of asking how to implement a solution which may not be optimal hth rob use strict use warning print match n if match orql lor sub match my input match foreach split match return unless input q return escapenumber to unsubscribe e mail beginner unsubscribe perl org for additional command e mail beginner help perl org http learn perl org',
#  'fathi boudra wrote i fixed the issue in the svn repo rev escapenumber fix dir config path in kdeglobals and kdesktoprc doesn t support symlink can you prepare an updated package please so that it will be included in etch rescapenumber address daniel baumann burgunderstrasse escapenumber ch escapenumber biberist email daniel baumann panthera system net internet http people panthera system net daniel baumann to unsubscribe email to debian desktop request list debian org with a subject of unsubscribe trouble contact listmaster list debian org']

# %%
words = [simple_preprocess(text) for text in corpus]

words[:5]
# Out:
# [['into',
#   'the',
#   'kingdom',
#   'of',
#   'god',
#   'and',
#   'those',
#   'that',
#   'are',
#   'entering',
#   'in',
#   'he',
#   'lord',
#   'pardon',
#   'escapenumber',
#   'in',
#   'this',
#   'thing',
#   'we',
#   'pray',
#   'thee',
#   'have',
#   'excused',
#   'escapenumbernot',
#   'therefore',
#   'escapenumber',
#   'believer',
#   'to',
#   'look',
#   'into',
#   'the',
#   'grave',
#   'for',
#   'to',
#   'you',
#   'it',
#   'the',
#   'holy',
#   'ghost',
#   'and',
#   'escapenumber',
#   'therefore',
#   'being',
#   'holy',
#   'habitation',
#   'unto',
#   'forth',
#   'the',
#   'word',
#   'of',
#   'truth',
#   'and',
#   'escapenumber',
#   'soberness',
#   'escapenumber',
#   'but',
#   'in',
#   'all',
#   'probability',
#   'hath',
#   'made',
#   'them',
#   'mad',
#   'escapenumber',
#   'and',
#   'though',
#   'escapenumber',
#   'blessed',
#   'be',
#   'god',
#   'all',
#   'do',
#   'that',
#   'of',
#   'jesus',
#   'christ',
#   'they',
#   'see',
#   'the',
#   'necessity',
#   'of',
#   'escapenumber',
#   'closing',
#   'with',
#   'more',
#   'than',
#   'almost',
#   'christian',
#   'but',
#   'is',
#   'heaven',
#   'so',
#   'small',
#   'escapenumber',
#   'trifle',
#   'in',
#   'men',
#   'esteem',
#   'not',
#   'to',
#   'be',
#   'total',
#   'renovation',
#   'of',
#   'the',
#   'whole',
#   'man',
#   'escapenumber',
#   'by',
#   'the',
#   'righteousness',
#   'of',
#   'complete',
#   'though',
#   'we',
#   'be',
#   'delivered',
#   'from',
#   'the',
#   'power',
#   'escapenumber',
#   'we',
#   'are',
#   'not',
#   'candle',
#   'of',
#   'the',
#   'lord',
#   'shine',
#   'out',
#   'and',
#   'your',
#   'redeemer',
#   'lift',
#   'up',
#   'the',
#   'escapenumber',
#   'inward',
#   'holiness',
#   'indeed',
#   'sometimes',
#   'they',
#   'do',
#   'though',
#   'in',
#   'worm',
#   'destroy',
#   'escapenumber',
#   'them',
#   'yet',
#   'even',
#   'in',
#   'their',
#   'flesh',
#   'shall',
#   'they',
#   'see',
#   'mind',
#   'to',
#   'see',
#   'jesus',
#   'but',
#   'escapenumber',
#   'then',
#   'they',
#   'cannot',
#   'come',
#   'to',
#   'him',
#   'jeannine',
#   'walsh'],
#  ['there',
#   'wa',
#   'flow',
#   'at',
#   'hpl',
#   'meter',
#   'on',
#   'april',
#   'first',
#   'that',
#   'didn',
#   'have',
#   'deal',
#   'ticket',
#   'out',
#   'there',
#   'but',
#   'now',
#   'there',
#   'is',
#   'deal',
#   'ticket',
#   'out',
#   'there',
#   'to',
#   'cover',
#   'it',
#   'please',
#   'link',
#   'it',
#   'or',
#   'whatever',
#   'you',
#   'have',
#   'to',
#   'do',
#   'to',
#   'make',
#   'it',
#   'work',
#   'thanks',
#   'lee'],
#  ['take',
#   'look',
#   'at',
#   'this',
#   'one',
#   'campaign',
#   'for',
#   'bvyhprice',
#   'escapenumber',
#   'escapenumber',
#   'escapenumber',
#   'day',
#   'target',
#   'price',
#   'escapenumber',
#   'hellish',
#   'this',
#   'sym',
#   'is',
#   'gaining',
#   'momentum',
#   'see',
#   'the',
#   'news',
#   'theescapenumber',
#   'call',
#   'your',
#   'broker'],
#  ['somu',
#   'wrote',
#   'actually',
#   'thats',
#   'what',
#   'wa',
#   'looking',
#   'for',
#   'so',
#   'if',
#   'the',
#   'user',
#   'entered',
#   'string',
#   'is',
#   'to',
#   'be',
#   'matched',
#   'for',
#   'lpt',
#   'then',
#   'll',
#   'use',
#   'and',
#   'to',
#   'match',
#   'npr',
#   'use',
#   'somu',
#   'you',
#   'need',
#   'to',
#   'tell',
#   'exactly',
#   'what',
#   'match',
#   'you',
#   'want',
#   'otherwise',
#   'we',
#   'can',
#   'tell',
#   'you',
#   'whether',
#   'something',
#   'will',
#   'work',
#   'or',
#   'not',
#   'are',
#   'you',
#   'simply',
#   'checking',
#   'whether',
#   'the',
#   'input',
#   'string',
#   'contains',
#   'all',
#   'of',
#   'the',
#   'match',
#   'character',
#   'would',
#   'forget',
#   'about',
#   'sorting',
#   'the',
#   'input',
#   'string',
#   'and',
#   'do',
#   'it',
#   'in',
#   'the',
#   'program',
#   'below',
#   'but',
#   'please',
#   'explain',
#   'what',
#   'the',
#   'problem',
#   'is',
#   'instead',
#   'of',
#   'asking',
#   'how',
#   'to',
#   'implement',
#   'solution',
#   'which',
#   'may',
#   'not',
#   'be',
#   'optimal',
#   'hth',
#   'rob',
#   'use',
#   'strict',
#   'use',
#   'warning',
#   'print',
#   'match',
#   'if',
#   'match',
#   'orql',
#   'lor',
#   'sub',
#   'match',
#   'my',
#   'input',
#   'match',
#   'foreach',
#   'split',
#   'match',
#   'return',
#   'unless',
#   'input',
#   'return',
#   'escapenumber',
#   'to',
#   'unsubscribe',
#   'mail',
#   'beginner',
#   'unsubscribe',
#   'perl',
#   'org',
#   'for',
#   'additional',
#   'command',
#   'mail',
#   'beginner',
#   'help',
#   'perl',
#   'org',
#   'http',
#   'learn',
#   'perl',
#   'org'],
#  ['fathi',
#   'boudra',
#   'wrote',
#   'fixed',
#   'the',
#   'issue',
#   'in',
#   'the',
#   'svn',
#   'repo',
#   'rev',
#   'escapenumber',
#   'fix',
#   'dir',
#   'config',
#   'path',
#   'in',
#   'kdeglobals',
#   'and',
#   'kdesktoprc',
#   'doesn',
#   'support',
#   'symlink',
#   'can',
#   'you',
#   'prepare',
#   'an',
#   'updated',
#   'package',
#   'please',
#   'so',
#   'that',
#   'it',
#   'will',
#   'be',
#   'included',
#   'in',
#   'etch',
#   'rescapenumber',
#   'address',
#   'daniel',
#   'baumann',
#   'escapenumber',
#   'ch',
#   'escapenumber',
#   'biberist',
#   'email',
#   'daniel',
#   'baumann',
#   'panthera',
#   'system',
#   'net',
#   'internet',
#   'http',
#   'people',
#   'panthera',
#   'system',
#   'net',
#   'daniel',
#   'baumann',
#   'to',
#   'unsubscribe',
#   'email',
#   'to',
#   'debian',
#   'desktop',
#   'request',
#   'list',
#   'debian',
#   'org',
#   'with',
#   'subject',
#   'of',
#   'unsubscribe',
#   'trouble',
#   'contact',
#   'listmaster',
#   'list',
#   'debian',
#   'org']]
